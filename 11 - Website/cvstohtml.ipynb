# %%
import pandas as pd

# %%
df = pd.read_csv("kelli_web/assets/data/cities_kelli.csv")
df.head()
# Out:
#            City Country  Latitude  Longitude  Temperature  Wind  Pressure  \
# 0    butaritari      PG    3.0707   172.7902        28.13  6.52    1013.0
# 1     cape town      PG  -33.9258    18.4232        10.04  1.54    1015.0
# 2         gusau      PG   12.1628     6.6614        23.86  6.49    1013.0
# 3      cidreira      PG  -30.1811   -50.2056        16.29  5.68    1019.0
# 4  puerto ayora      PG   -0.7393   -90.3518        21.97  3.58    1013.0
#
#    Humidity  Cloudiness          Date
# 0      66.0        11.0  1.628377e+09
# 1     100.0        90.0  1.628377e+09
# 2      86.0        83.0  1.628377e+09
# 3      90.0         2.0  1.628377e+09
# 4      84.0        68.0  1.628377e+09

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Wind</th>
#       <th>Pressure</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>butaritari</td>
#       <td>PG</td>
#       <td>3.0707</td>
#       <td>172.7902</td>
#       <td>28.13</td>
#       <td>6.52</td>
#       <td>1013.0</td>
#       <td>66.0</td>
#       <td>11.0</td>
#       <td>1.628377e+09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cape town</td>
#       <td>PG</td>
#       <td>-33.9258</td>
#       <td>18.4232</td>
#       <td>10.04</td>
#       <td>1.54</td>
#       <td>1015.0</td>
#       <td>100.0</td>
#       <td>90.0</td>
#       <td>1.628377e+09</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...
